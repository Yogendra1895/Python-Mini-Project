# %%
import pandas as pd
df= pd.read_csv(r"C:\Users\DELL\Desktop\Video-games-project\Video_Games1.csv")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# #### Count missing values

# %%
 df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %% [markdown]
# #### Data-types od each columns

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %% [markdown]
# #### Data handling

# %%
from sklearn.impute import SimpleImputer   # Used to fill missing values in dataset.

# %%
imputer = SimpleImputer(strategy = "most_frequent")

df[["Name","Genre","Publisher","User_Score","Developer","Rating"]]=imputer.fit_transform(df[["Name","Genre","Publisher","User_Score","Developer","Rating"]])

# %%
imputer=SimpleImputer(strategy="median")

df[["Year_of_Release","Critic_Score","Critic_Count","User_Count"]]=imputer.fit_transform(df[["Year_of_Release","Critic_Score","Critic_Count","User_Count"]])

# %% [markdown]
# #### Checking the null values

# %%
df.isnull().sum()
# Out:
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %% [markdown]
# #### 1. Get sample of 5 rows

# %%
sample= df.sample(5)
sample
# Out:
#                                      Name Platform  Year_of_Release  \
# 3249   XGRA: Extreme G-Racing Association      PS2           2004.0
# 14275        James Pond: Codename Robocod      GBA           2005.0
# 14717       Gudetama: Hanjuku de Tanomuwa      3DS           2015.0
# 292                    Fallout: New Vegas     X360           2010.0
# 1174                       Mario Party 10     WiiU           2015.0
#
#               Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 3249         Racing   Eidos Interactive      0.30      0.24      0.00
# 14275      Platform             Play It      0.02      0.01      0.00
# 14717        Action      Rocket Company      0.00      0.00      0.03
# 292    Role-Playing  Bethesda Softworks      2.66      1.03      0.04
# 1174           Misc            Nintendo      0.69      0.53      0.24
#
#        Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# ...

# %% [markdown]
# #### 2. Display all the columns

# %%
columns= df.columns
columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %% [markdown]
# #### 3. Display the dimensions

# %%
dimensions= df.shape
print("Dimension of video game dataset: ")
dimensions
# Out:
# Dimension of video game dataset:
# (16719, 16)

# %% [markdown]
# #### 4. Dispaly all columns data types

# %%
columns_dt= df.dtypes
columns_dt
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %% [markdown]
# #### 5. Display Top 10 rows

# %%
dat= df.head(10)
print("Top 10 rows:")
dat
# Out:
# Top 10 rows:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %% [markdown]
# #### 6. Bottom 10 rows

# %%
dat1= df.tail(10)
print("Bottom 10 rows:")
dat1
# Out:
# Bottom 10 rows:
#                                                    Name Platform  \
# 16709                                           15 Days       PC
# 16710                     Men in Black II: Alien Escape       GC
# 16711                                  Aiyoku no Eustia      PSV
# 16712                Woody Woodpecker in Crazy Castle 5      GBA
# 16713  SCORE International Baja 1000: The Official Game      PS2
# 16714                     Samurai Warriors: Sanada Maru      PS3
# 16715                                  LMA Manager 2007     X360
# 16716                           Haitaka no Psychedelica      PSV
# 16717                                  Spirits & Spells      GBA
# 16718                               Winning Post 8 2016      PSV
#
#        Year_of_Release       Genre          Publisher  NA_Sales  EU_Sales  \
# 16709           2009.0   Adventure  DTP Entertainment      0.00      0.01
# 16710           2003.0     Shooter         Infogrames      0.01      0.00
# ...

# %% [markdown]
# #### 7. Display all Racing Games which have Critic_score >= 95.

# %%
import pandas as pd
result= df[(df['Genre'] == 'Racing') & (df['Critic_Score'] >= 95)]
result
# Out:
#                       Name Platform  Year_of_Release   Genre  \
# 28  Gran Turismo 3: A-Spec      PS2           2001.0  Racing
# 52            Gran Turismo       PS           1997.0  Racing
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 28  Sony Computer Entertainment      6.85      5.09      1.87         1.16
# 52  Sony Computer Entertainment      4.02      3.87      2.54         0.52
#
#     Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 28         14.98          95.0          54.0        8.4       314.0
# 52         10.95          96.0          16.0        8.7       138.0
#
#             Developer Rating
# 28  Polyphony Digital      E
# 52  Polyphony Digital      E

# %% [markdown]
# #### 8. Display video games whos user_score>9.

# %%
df['User_Score'] = pd.to_numeric(df['User_Score'], errors='coerce')  # Convert datatypes
high_rated_games = df.loc[df['User_Score'] > 9.0, 'Name']
print(high_rated_games)
# Out:
# 65                               Final Fantasy VII
# 97                            Super Mario Galaxy 2
# 106                                       Tekken 3
# 110                                   Mario Kart 8
# 111                        Super Smash Bros. Melee
#                            ...
# 16230                    Monster Rancher Advance 2
# 16355                                      Deus Ex
# 16433    Greg Hastings' Tournament Paintball Max'd
# 16550                  Wade Hixton's Counter Punch
# 16631                                Karnaaj Rally
# Name: Name, Length: 184, dtype: object

# %% [markdown]
# #### 9. Display all unique user_scores

# %%
unique_unser_score= df['User_Score'].unique()
unique_unser_score
# Out:
# array([8. , nan, 8.3, 8.5, 6.6, 8.4, 8.6, 7.7, 6.3, 7.4, 8.2, 9. , 7.9,
#        8.1, 8.7, 7.1, 3.4, 5.3, 4.8, 3.2, 8.9, 6.4, 7.8, 7.5, 2.6, 7.2,
#        9.2, 7. , 7.3, 4.3, 7.6, 5.7, 5. , 9.1, 6.5, 8.8, 6.9, 9.4, 6.8,
#        6.1, 6.7, 5.4, 4. , 4.9, 4.5, 9.3, 6.2, 4.2, 6. , 3.7, 4.1, 5.8,
#        5.6, 5.5, 4.4, 4.6, 5.9, 3.9, 3.1, 2.9, 5.2, 3.3, 4.7, 5.1, 3.5,
#        2.5, 1.9, 3. , 2.7, 2.2, 2. , 9.5, 2.1, 3.6, 2.8, 1.8, 3.8, 0. ,
#        1.6, 9.6, 2.4, 1.7, 1.1, 0.3, 1.5, 0.7, 1.2, 2.3, 0.5, 1.3, 0.2,
#        0.6, 1.4, 0.9, 1. , 9.7])

# %% [markdown]
# #### 10. Display all types of Games

# %%
unique_games = df['Genre'].unique()
print(unique_games)
# Out:
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']

# %% [markdown]
# #### 11. Access row 15

# %%
row_15= df.loc[14]
row_15
# Out:
# Name                   Kinect Adventures!
# Platform                             X360
# Year_of_Release                    2010.0
# Genre                                Misc
# Publisher          Microsoft Game Studios
# NA_Sales                             15.0
# EU_Sales                             4.89
# JP_Sales                             0.24
# Other_Sales                          1.69
# Global_Sales                        21.81
# Critic_Score                         61.0
# Critic_Count                         45.0
# User_Score                            6.3
# User_Count                          106.0
# Developer             Good Science Studio
# Rating                                  E
# Name: 14, dtype: object

# %% [markdown]
# #### 12. Display EU_Sales,Global_Sales and Critic_Count of all games using iloc

# %%
# df.head(5)
result = df.iloc[:,[6,9,11]]
result
# Out:
#        EU_Sales  Global_Sales  Critic_Count
# 0         28.96         82.53          51.0
# 1          3.58         40.24          21.0
# 2         12.76         35.52          73.0
# 3         10.93         32.77          73.0
# 4          8.89         31.37          21.0
# ...         ...           ...           ...
# 16714      0.00          0.01          21.0
# 16715      0.01          0.01          21.0
# 16716      0.00          0.01          21.0
# 16717      0.00          0.01          21.0
# 16718      0.00          0.01          21.0
#
# [16719 rows x 3 columns]

# %% [markdown]
# #### 13. Display the Name, Genre, and Developer of all games using loc

# %%
result = df.loc[:,['Name', 'Genre', 'Developer']].drop_duplicates()
result
# Out:
#                                      Name         Genre Developer
# 0                              Wii Sports        Sports  Nintendo
# 1                       Super Mario Bros.      Platform   Ubisoft
# 2                          Mario Kart Wii        Racing  Nintendo
# 3                       Wii Sports Resort        Sports  Nintendo
# 4                Pokemon Red/Pokemon Blue  Role-Playing   Ubisoft
# ...                                   ...           ...       ...
# 16710       Men in Black II: Alien Escape       Shooter     Atari
# 16711                    Aiyoku no Eustia          Misc   Ubisoft
# 16712  Woody Woodpecker in Crazy Castle 5      Platform   Ubisoft
# 16715                    LMA Manager 2007        Sports   Ubisoft
# 16716             Haitaka no Psychedelica     Adventure   Ubisoft
#
# [12707 rows x 3 columns]

# %% [markdown]
# #### 14. Which developer has made how much sales in USD gloabally

# %%
total_sales = df.groupby('Developer') ['Global_Sales'].sum()
total_sales
# Out:
# Developer
# 10tacle Studios                          0.16
# 10tacle Studios, Fusionsphere Systems    0.11
# 1C, 1C Company                           0.03
# 1C, Ino-Co, 1C Company                   0.05
# 1C, Various, 1C Company                  0.01
#                                          ...
# odenis studio                            0.09
# oeFun                                    0.02
# puzzle.tv                                0.12
# syn Sophia                               3.31
# zSlide                                   0.03
# Name: Global_Sales, Length: 1696, dtype: float64

# %% [markdown]
# #### 15. Remove all null values from User_Score

# %%
Result = df.dropna(subset = ['User_Score'])
Result
# Out:
#                                     Name Platform  Year_of_Release      Genre  \
# 0                             Wii Sports      Wii           2006.0     Sports
# 2                         Mario Kart Wii      Wii           2008.0     Racing
# 3                      Wii Sports Resort      Wii           2009.0     Sports
# 6                  New Super Mario Bros.       DS           2006.0   Platform
# 7                               Wii Play      Wii           2006.0       Misc
# ...                                  ...      ...              ...        ...
# 16685                            Worms 2       PC           1997.0   Strategy
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0     Action
# 16700                             Breach       PC           2011.0    Shooter
# 16706            STORM: Frontline Nation       PC           2011.0   Strategy
# 16709                            15 Days       PC           2009.0  Adventure
#
# ...

# %% [markdown]
# #### 16. Plot the histogram chart with x=User_Score and y=Developer

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.hist(df["User_Score"], bins=18, color="grey",edgecolor='white')
plt.title('Histogram of Global Sales')
plt.xlabel('User_Score')
plt.ylabel('Developer')
# Out:
# Text(0, 0.5, 'Developer')

# %% [markdown]
# #### 17. Display all video games.

# %%
video_games = df.Name.unique()
print("All video games: \n",video_games)
# Out:
# All video games:
#  ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ...
#  'Woody Woodpecker in Crazy Castle 5' 'LMA Manager 2007'
#  'Haitaka no Psychedelica']

# %% [markdown]
# #### 18. Update NA_Sales with + 5:  (map with lambda)

# %%
NA_Sales_update = df["NA_Sales"].map(lambda x : x+5)
NA_Sales_update
# Out:
# 0        46.36
# 1        34.08
# 2        20.68
# 3        20.61
# 4        16.27
#          ...
# 16714     5.00
# 16715     5.00
# 16716     5.00
# 16717     5.01
# 16718     5.00
# Name: NA_Sales, Length: 16719, dtype: float64

# %% [markdown]
# #### 19. Display which Genre has how many games.

# %%
all_games =  df.groupby('Genre')['Genre'].count()
all_games
# Out:
# Genre
# Action          3372
# Adventure       1303
# Fighting         849
# Misc            1750
# Platform         888
# Puzzle           580
# Racing          1249
# Role-Playing    1500
# Shooter         1323
# Simulation       874
# Sports          2348
# Strategy         683
# Name: Genre, dtype: int64

# %% [markdown]
# #### 20. Create a bar chart for all games.

# %%
plt.figure(figsize=(10,6))

All_Genre = df['Genre'].value_counts()
All_Genre.plot(kind='bar', color="blue",edgecolor="black")

plt.xlabel('Genre')
plt.ylabel('Number of Games')
plt.title('Number of Games per Genre')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### 21. Which developer has most games sold:- top 20 developer.

# %%
top_developers = (
    df.groupby("Developer")["Global_Sales"].sum().sort_values(ascending=False).head(20).reset_index()
)
print(top_developers)
# Out:
#                   Developer  Global_Sales
# 0                   Ubisoft       2962.00
# 1                  Nintendo        531.71
# 2                 EA Sports        175.38
# 3                 EA Canada        142.32
# 4            Rockstar North        119.47
# 5                    Capcom        115.71
# 6          Ubisoft Montreal        108.31
# 7                  Treyarch        103.16
# 8                EA Tiburon         96.12
# 9         Traveller's Tales         79.22
# 10            Infinity Ward         77.62
# 11          Visual Concepts         72.87
# 12                   Konami         72.56
# 13          Electronic Arts         66.26
# 14        Polyphony Digital         65.20
# 15                    Namco         63.11
# 16  Neversoft Entertainment         61.27
# 17        Vicarious Visions         56.98
# 18               SquareSoft         54.65
# 19              Square Enix         52.15

# %% [markdown]
# #### 22. Plot the bar chart for the above top 20 developers.

# %%
plt.figure(figsize=(10,5))

Top_20_Developers = df.groupby('Developer')['Global_Sales'].sum()

Top_20_Developers.plot(kind='bar',color='green', edgecolor='black')

plt.xlabel('Developer')
plt.ylabel('Total Global Sales (in millions)')
plt.title('Top 20 Developers by Global Sales')
plt.xticks(rotation=90)
plt.show()

# %%
Top_20_Developers = df.groupby('Developer')['Global_Sales'].sum().sort_values(ascending=False).head(20)

plt.figure(figsize=(10, 6))  
Top_20_Developers.plot(kind='bar', color='green', edgecolor='black')

plt.xlabel('Developer')
plt.ylabel('Total Global Sales (in millions)')
plt.title('Top 20 Developers by Global Sales')
# Out:
# Text(0.5, 1.0, 'Top 20 Developers by Global Sales')
